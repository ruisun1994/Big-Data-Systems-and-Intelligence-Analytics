# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import os as os
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
df = pd.DataFrame(pd.read_csv('matches.csv',engine='python'))
# Out:
#   File "<ipython-input-8-2f953eab048e>", line 8
#     df = pd.DataFrame(pd.read_csv('matches.csv',engine=‘python’))
#                                                               ^
# SyntaxError: invalid character in identifier

# %%
df
# Out:
#                                                  Address      Team  \
# 0      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 1      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 2      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 3      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 4      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 5      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 6      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 7      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 8      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 9      http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 10     http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 11     http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# 12     http://matchhistory.na.leagueoflegends.com/en/...  blueBans
# ...
